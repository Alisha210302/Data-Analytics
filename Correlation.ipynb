# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('weight-height.csv')

# %%
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
df_male = df[df['Gender']=='Male']
df_female = df[df['Gender']=='Female']

# %%
# calculate correlation
corr_overall = df[['Height', 'Weight']].corr()
corr_male = df_male[['Height', 'Weight']].corr()
corr_female = df_female[['Height', 'Weight']].corr()

# %%
print('Overall correlation between height and weight: ')
corr_overall
# Out:
# Overall correlation between height and weight:
#           Height    Weight
# Height  1.000000  0.924756
# Weight  0.924756  1.000000

# %%
print('Male correlation between height and weight: ')
corr_male
# Out:
# Male correlation between height and weight:
#           Height    Weight
# Height  1.000000  0.862979
# Weight  0.862979  1.000000

# %%
print('Female correlation between height and weight: ')
corr_female
# Out:
# Female correlation between height and weight:
#           Height    Weight
# Height  1.000000  0.849609
# Weight  0.849609  1.000000

# %%
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
# calculate covariance
cov_overall = df[['Height', 'Weight']].cov()
cov_male = df_male[['Height', 'Weight']].cov()
cov_female = df_female[['Height', 'Weight']].cov()

# %%
print('Overall covariance between height and weight: ')
cov_overall
# Out:
# Overall covariance between height and weight:
#             Height       Weight
# Height   14.803473   114.242656
# Weight  114.242656  1030.951855

# %%
print('Male covariance between height and weight: ')
cov_male
# Out:
# Male covariance between height and weight:
#            Height      Weight
# Height   8.198843   48.879649
# Weight  48.879649  391.294074

# %%
print('Female covariance between height and weight: ')
cov_female
# Out:
# Female covariance between height and weight:
#            Height      Weight
# Height   7.269947   43.576404
# Weight  43.576404  361.854281

# %%
fig , axes = plt.subplots(1,3,figsize=(18,6))
# overall data plot
axes[0].scatter(df['Height'],df['Weight'],color='blue',alpha=0.5)
axes[0].set_title(f'Overall Correlation: {corr_overall.loc['Height','Weight']:.2f}')
axes[0].set_xlabel('Height')
axes[0].grid(True)

#Male data plot 
axes[1].scatter(df_male['Height'],df_male['Weight'],color='green',alpha=0.5)
axes[1].set_title(f"Male Correlation:{corr_male.loc['Height','Weight']:.2f}")
axes[1].set_xlabel('Height')
axes[1].set_ylabel('Weight')
axes[1].grid(True)

axes[2].scatter(df_female['Height'],df_female['Weight'],color = 'red',alpha=0.5)
axes[2].set_title(f"female Correlation: {corr_female.loc['Height','Weight']:.2f}")
axes[2].set_xlabel('Height')
axes[2].grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## SP500 oil gold bitcoin.csv

# %%
df2 = pd.read_csv('SP500 oil gold bitcoin.csv')
df2.head()
# Out:
#          Date  BITCOIN  Brent Oil  Crude Oil WTI    Gold   S&P500
# 0  2010-07-18      0.1      75.37          76.01  1188.0  1064.88
# 1  2010-07-19      0.1      75.62          76.54  1181.7  1071.25
# 2  2010-07-20      0.1      76.22          77.44  1191.5  1083.48
# 3  2010-07-21      0.1      75.37          76.56  1191.6  1069.59
# 4  2010-07-22      0.1      77.82          79.30  1195.5  1093.67

# %%
# calculate correlation
corr_BITCOIN = df2[['BITCOIN', 'Gold']].corr()
corr_Gold = df2[['BITCOIN', 'S&P500']].corr()

# %%
fig , axes = plt.subplots(1,2,figsize=(18,6))
# axes[0].scatter(df['BITCOIN'], df['Gold'])
# plt.text(text_x, text_y, f"Correlation: {bit_sp.loc['BITCOIN', 'S&P500']:.2f}", ha='center', va='center', fontsize=12)
axes[1].scatter(corr_BITCOIN['BITCOIN'],corr_BITCOIN['Gold'],color='green',alpha=0.5)
axes[1].set_title(f"Correlation:{corr_BITCOIN.loc['BITCOIN','Gold']:.2f}")
axes[1].set_xlabel('BITCOIN')
axes[1].set_ylabel('GOLD')
axes[1].grid(True)

atter(corr_Gold['BITCOIN'],corr_BITCOIN['S&P500'],color='green',alpha=0.5)
axes[0].set_title(f"Correlation:{corr_Gold.loc['BITCOIN','S&P500']:.2f}")
axes[0].set_xlabel('BITCOIN')
axes[0].set_ylabel('S&P500')
axes[0].grid(True)

# useful when you want to place elements like text at a specific location
# relative to the axis limits rather than using fix coordinates
xmin, xmax = plt.xlim()
ymin, ymax = plt.ylim()

# Set the text position at 70% of the x-axis and 30% of the y-axis range
text_x = xmin + 0.7 * (xmax - xmin)
text_y = ymin + 0.3 * (ymax - ymin)

plt.text(text_x, text_y, f"Correlation: {corr_BITCOIN.loc['BITCOIN', 'Gold']:.2f}", ha='center', va='center', fontsize=12)
axes[1].set_title(f"Male Correlation:{corr_BITCOIN.loc['BITCOIN','Gold']:.2f}")

plt.grid(True)
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 10
#       7 axes[1].set_ylabel('GOLD')
#       8 axes[1].grid(True)
# ---> 10 atter(corr_Gold['BITCOIN'],corr_BITCOIN['S&P500'],color='green',alpha=0.5)
#      11 axes[0].set_title(f"Correlation:{corr_Gold.loc['BITCOIN','S&P500']:.2f}")
#      12 axes[0].set_xlabel('BITCOIN')
#
# NameError: name 'atter' is not defined
